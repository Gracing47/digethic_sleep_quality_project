# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Liste der Variablen
variablen = [
    'Caffeine_Intake_mg',
    'Movement_During_Sleep',
    'Sleep_Duration_Hours',
    'Light_Exposure_hours',
    'Bedtime_Consistency',
    'Heart_Rate_Variability'
]

# Anzahl der Variablen
anzahl_variablen = len(variablen)
anzahl_spalten = 3
anzahl_zeilen = (anzahl_variablen + anzahl_spalten - 1) // anzahl_spalten

# Histogramme mit Dichtekurven
plt.figure(figsize=(anzahl_spalten * 5, anzahl_zeilen * 4))

for i, var in enumerate(variablen):
    plt.subplot(anzahl_zeilen, anzahl_spalten, i + 1)
    sns.histplot(df[var], kde=True, bins=30, color='skyblue', edgecolor='black')
    plt.title(var, fontsize=12)
    plt.xlabel('')
    plt.ylabel('Häufigkeit')

plt.tight_layout()
plt.show()

# Boxplots
plt.figure(figsize=(anzahl_spalten * 5, anzahl_zeilen * 3))

for i, var in enumerate(variablen):
    plt.subplot(anzahl_zeilen, anzahl_spalten, i + 1)
    sns.boxplot(x=df[var], color='lightgreen')
    plt.title(var, fontsize=12)
    plt.xlabel('')

plt.tight_layout()
plt.show()

df
